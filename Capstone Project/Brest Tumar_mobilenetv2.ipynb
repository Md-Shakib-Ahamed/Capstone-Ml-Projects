# %% [markdown]
# # **# 🧱 সেল–০: Colab সেটআপ (TF, utils)**

# %%
# ===== Cell 0: Base setup =====
# !pip install -q tensorflow==2.15.0 scikit-learn matplotlib flask flask-cors pyngrok -U

import os, json, random, warnings, glob, io, time
warnings.filterwarnings("ignore")

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from collections import Counter

SEED = 42
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

print(tf.__version__)
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.15.0 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0, 2.19.1, 2.20.0rc0, 2.20.0)
# ERROR: No matching distribution found for tensorflow==2.15.0
# 2.19.0

# %% [markdown]
# # **🗂️ সেল–১: ড্রাইভ মাউন্ট + পাথ**

# %%
# ===== Cell 1: Drive & paths =====
from google.colab import drive
drive.mount('/content/drive')

# EDIT THESE to your paths
BUSI_DIR = "/content/drive/MyDrive/CSE-51/8Th/Capstone/Alternative data/Breast Ultra Image/Dataset_BUSI_with_GT"
OUT_DIR  = "/content/drive/MyDrive/CSE-51/8Th/Capstone/Breast_Models"

os.makedirs(OUT_DIR, exist_ok=True)

CLASSES = ["benign", "malignant", "normal"]  # fixed order (stable API)
class_to_idx = {c:i for i,c in enumerate(CLASSES)}
idx_to_class = {i:c for c,i in class_to_idx.items()}

print("BUSI_DIR:", BUSI_DIR)
print("OUT_DIR :", OUT_DIR)
print("Classes :", CLASSES)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# BUSI_DIR: /content/drive/MyDrive/CSE-51/8Th/Capstone/Alternative data/Breast Ultra Image/Dataset_BUSI_with_GT
# OUT_DIR : /content/drive/MyDrive/CSE-51/8Th/Capstone/Breast_Models
# Classes : ['benign', 'malignant', 'normal']

# %% [markdown]
# # **📥 সেল–২: ডেটা লোড/সপ্লিট + tf.data**

# %%
# ===== Cell 2: Gather & split =====
paths, labels = [], []
for cls in CLASSES:
    cdir = os.path.join(BUSI_DIR, cls)
    imgs = sorted(glob.glob(os.path.join(cdir, "*.png"))) + \
           sorted(glob.glob(os.path.join(cdir, "*.jpg"))) + \
           sorted(glob.glob(os.path.join(cdir, "*.jpeg")))
    imgs = [p for p in imgs if not p.lower().endswith("_mask.png")]
    paths.extend(imgs)
    labels.extend([cls]*len(imgs))

assert len(paths) > 0, "No images found. Check BUSI_DIR."
y = np.array([class_to_idx[l] for l in labels])

for c in CLASSES:
    print(f"{c}: {sum(1 for L in labels if L==c)}")

with open(os.path.join(OUT_DIR, "labels.json"), "w") as f:
    json.dump({str(k):v for k,v in idx_to_class.items()}, f, indent=2)

X_temp, X_test, y_temp, y_test = train_test_split(paths, y, test_size=0.15, stratify=y, random_state=SEED)
X_train, X_val,  y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.1765, stratify=y_temp, random_state=SEED)
print(f"Split → train={len(X_train)} | val={len(X_val)} | test={len(X_test)}")

IMG_SIZE   = (224, 224)
BATCH_SIZE = 32

@tf.function
def load_image(path, label):
    img = tf.io.read_file(path)
    img = tf.io.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, IMG_SIZE)
    img = tf.cast(img, tf.float32) / 255.0
    return img, label

aug = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
], name="augment")

def build_ds(X, y, training):
    ds = tf.data.Dataset.from_tensor_slices((X, y))
    ds = ds.shuffle(len(X), seed=SEED) if training else ds
    ds = ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
    if training:
        ds = ds.map(lambda a,b: (aug(a, training=True), b), num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

ds_train = build_ds(X_train, y_train, training=True)
ds_val   = build_ds(X_val,   y_val,   training=False)
ds_test  = build_ds(X_test,  y_test,  training=False)

cnt = Counter(y_train)
total = sum(cnt.values())
class_weight = {i: total/(len(CLASSES)*cnt.get(i,1)) for i in range(len(CLASSES))}
print("Class weights:", class_weight)
# Out:
# benign: 454
# malignant: 211
# normal: 133
# Split → train=558 | val=120 | test=120
# Class weights: {0: 0.5849056603773585, 1: 1.2653061224489797, 2: 2.0}

# %% [markdown]
# # **🧠 সেল–৩: মডেল ট্রেনিং + ফাইন-টিউন + সেভ**

# %%
# ===== Cell 3: Train & fine-tune =====
base = tf.keras.applications.MobileNetV2(include_top=False, weights="imagenet",
                                         input_shape=IMG_SIZE+(3,))
base.trainable = False

inputs = keras.Input(shape=IMG_SIZE+(3,))
x = base(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(len(CLASSES), activation="softmax")(x)
model = keras.Model(inputs, outputs)

model.compile(optimizer=keras.optimizers.Adam(1e-3),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

ckpt = os.path.join(OUT_DIR, "busi_mobilenetv2_best.keras")
callbacks = [
    keras.callbacks.ModelCheckpoint(ckpt, monitor="val_accuracy", save_best_only=True, verbose=1),
    keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=6, restore_best_weights=True, verbose=1),
    keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6, verbose=1)
]

print("Training (frozen)…")
model.fit(ds_train, validation_data=ds_val, epochs=20,
          class_weight=class_weight, callbacks=callbacks, verbose=1)

base.trainable = True
for layer in base.layers[:-30]:
    layer.trainable = False

model.compile(optimizer=keras.optimizers.Adam(1e-5),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

print("Fine-tuning (top layers)…")
model.fit(ds_train, validation_data=ds_val, epochs=10,
          class_weight=class_weight, callbacks=callbacks, verbose=1)

best_model = keras.models.load_model(ckpt)

# Evaluate
test_loss, test_acc = best_model.evaluate(ds_test, verbose=0)
print(f"Test accuracy: {test_acc:.3f} | loss: {test_loss:.3f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training (frozen)…
# Epoch 1/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.4275 - loss: 1.4247
# Epoch 1: val_accuracy improved from -inf to 0.52500, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Breast_Models/busi_mobilenetv2_best.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 266s 13s/step - accuracy: 0.4261 - loss: 1.4200 - val_accuracy: 0.5250 - val_loss: 0.9914 - learning_rate: 0.0010
# Epoch 2/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.5032 - loss: 1.0357
# Epoch 2: val_accuracy improved from 0.52500 to 0.55833, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Breast_Models/busi_mobilenetv2_best.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 615ms/step - accuracy: 0.5041 - loss: 1.0345 - val_accuracy: 0.5583 - val_loss: 0.9552 - learning_rate: 0.0010
# Epoch 3/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.5654 - loss: 0.8641
# Epoch 3: val_accuracy improved from 0.55833 to 0.61667, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Breast_Models/busi_mobilenetv2_best.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 670ms/step - accuracy: 0.5671 - loss: 0.8634 - val_accuracy: 0.6167 - val_loss: 0.8705 - learning_rate: 0.0010
# Epoch 4/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.5886 - loss: 0.8190
# Epoch 4: val_accuracy improved from 0.61667 to 0.66667, saving model to /content/drive/MyDrive/CSE-51/8Th/Capstone/Breast_Models/busi_mobilenetv2_best.keras
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 652ms/step - accuracy: 0.5900 - loss: 0.8189 - val_accuracy: 0.6667 - val_loss: 0.7541 - learning_rate: 0.0010
# Epoch 5/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - accuracy: 0.6734 - loss: 0.7508
# Epoch 5: val_accuracy did not improve from 0.66667
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 598ms/step - accuracy: 0.6725 - loss: 0.7507 - val_accuracy: 0.5500 - val_loss: 0.9615 - learning_rate: 0.0010
# Epoch 6/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.6543 - loss: 0.7723
# Epoch 6: val_accuracy did not improve from 0.66667
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 579ms/step - accuracy: 0.6541 - loss: 0.7717 - val_accuracy: 0.6083 - val_loss: 0.8383 - learning_rate: 0.0010
# Epoch 7/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.6762 - loss: 0.6800
# Epoch 7: val_accuracy did not improve from 0.66667
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 561ms/step - accuracy: 0.6765 - loss: 0.6802 - val_accuracy: 0.6500 - val_loss: 0.8056 - learning_rate: 0.0010
# Epoch 8/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.7115 - loss: 0.6375
# Epoch 8: val_accuracy did not improve from 0.66667
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 642ms/step - accuracy: 0.7101 - loss: 0.6400 - val_accuracy: 0.6333 - val_loss: 0.8018 - learning_rate: 5.0000e-04
# Epoch 9/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - accuracy: 0.7092 - loss: 0.6665
# Epoch 9: val_accuracy did not improve from 0.66667
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 598ms/step - accuracy: 0.7080 - loss: 0.6666 - val_accuracy: 0.6583 - val_loss: 0.8151 - learning_rate: 5.0000e-04
# Epoch 10/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.6943 - loss: 0.6422
# Epoch 10: val_accuracy did not improve from 0.66667
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 602ms/step - accuracy: 0.6950 - loss: 0.6425 - val_accuracy: 0.6500 - val_loss: 0.7681 - learning_rate: 5.0000e-04
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Fine-tuning (top layers)…
# Epoch 1/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - accuracy: 0.5926 - loss: 2.0334
# Epoch 1: val_accuracy did not improve from 0.66667
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.5935 - loss: 2.0277 - val_accuracy: 0.6583 - val_loss: 0.7809 - learning_rate: 1.0000e-05
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.6669 - loss: 1.5533
# Epoch 2: val_accuracy did not improve from 0.66667
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 549ms/step - accuracy: 0.6648 - loss: 1.5623 - val_accuracy: 0.6333 - val_loss: 0.8028 - learning_rate: 1.0000e-05
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.6391 - loss: 1.4943
# Epoch 3: val_accuracy did not improve from 0.66667
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 558ms/step - accuracy: 0.6394 - loss: 1.4944 - val_accuracy: 0.6500 - val_loss: 0.8200 - learning_rate: 1.0000e-05
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - accuracy: 0.6808 - loss: 1.2352
# Epoch 4: val_accuracy did not improve from 0.66667
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 612ms/step - accuracy: 0.6801 - loss: 1.2352 - val_accuracy: 0.6500 - val_loss: 0.8277 - learning_rate: 1.0000e-05
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - accuracy: 0.6671 - loss: 1.1787
# Epoch 5: val_accuracy did not improve from 0.66667
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 640ms/step - accuracy: 0.6678 - loss: 1.1715 - val_accuracy: 0.6500 - val_loss: 0.8318 - learning_rate: 5.0000e-06
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.6622 - loss: 1.1110
# Epoch 6: val_accuracy did not improve from 0.66667
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 623ms/step - accuracy: 0.6635 - loss: 1.1053 - val_accuracy: 0.6417 - val_loss: 0.8345 - learning_rate: 5.0000e-06
# Epoch 7/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.6983 - loss: 0.8654
# Epoch 7: val_accuracy did not improve from 0.66667
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 534ms/step - accuracy: 0.6969 - loss: 0.8695 - val_accuracy: 0.6417 - val_loss: 0.8376 - learning_rate: 5.0000e-06
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Test accuracy: 0.700 | loss: 0.720

# %% [markdown]
# # **💾 সেল–৪: TFLite এক্সপোর্ট + ইউটিলস**

# %%
# ===== Cell 4: Export TFLite & utils =====
tflite_path = os.path.join(OUT_DIR, "busi_mobilenetv2.tflite")
converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()
with open(tflite_path, "wb") as f:
    f.write(tflite_model)
print("TFLite:", tflite_path)
print("Labels:", os.path.join(OUT_DIR, "labels.json"))

# ---- Inference helpers (shared by API) ----
def preprocess_bytes(image_bytes, size=(224,224)):
    from PIL import Image
    img = Image.open(io.BytesIO(image_bytes)).convert("RGB")
    img = img.resize(size)
    arr = np.array(img)/255.0
    arr = np.expand_dims(arr, 0).astype(np.float32)
    return arr

def load_tflite(tflite_path):
    intr = tf.lite.Interpreter(model_path=tflite_path)
    intr.allocate_tensors()
    inp = intr.get_input_details()[0]['index']
    out = intr.get_output_details()[0]['index']
    return intr, inp, out

interpreter, input_index, output_index = load_tflite(tflite_path)
with open(os.path.join(OUT_DIR,"labels.json"), "r") as f:
    idx_to_class = {int(k):v for k,v in json.load(f).items()}

def infer_probs(image_bytes):
    arr = preprocess_bytes(image_bytes, IMG_SIZE)
    interpreter.set_tensor(input_index, arr)
    interpreter.invoke()
    probs = interpreter.get_tensor(output_index)[0]  # (3,)
    return probs
# Out:
# Saved artifact at '/tmp/tmpatvx1045'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   140122707230352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122707228624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122706368208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122706378384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122707230544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244220112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244220496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244220304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244219152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244221072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244219536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244220688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244220880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244219728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244222032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244221456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244221648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244221840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244219344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244222992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244222416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244222608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244222800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244218960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244223952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244223376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244223568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244223760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244221264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244224912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244224336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244224528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244224720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244222224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244225872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244225296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244225488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244225680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244223184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244226832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244226256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244226448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244226640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244224144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244227792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244227216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244227408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244227600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244225104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244228752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244228176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244228368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244228560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244226064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244229712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244229136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244229328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244229520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244227024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244230672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244230096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244230288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244230480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244227984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244231632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244231056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244231248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244231440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244228944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244232592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244232016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244232208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244232400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244233552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244232976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244233168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244233360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244230864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244234512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244233936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244234128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244234704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244235088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244233744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244232784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244234320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242942160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244234896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122244231824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242941200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242941584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242941776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242941968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242943120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242942544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242942736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242942928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242941008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242944080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242943504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242943696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242943888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242941392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242945040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242944464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242944656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242944848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242942352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242946000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242945424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242945616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242945808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242943312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242946960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242946384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242946576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242946768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242944272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242947920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242947344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242947536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242947728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242945232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242948880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242948304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242948496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242948688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242946192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242949840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242949264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242949456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242949648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242947152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242950800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242950224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242950416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242950608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242948112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242951760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242951184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242951376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242951568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242949072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242952720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242952144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242952336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242952528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242950032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242953680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242953104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242953296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242953488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242950992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242954640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242954064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242954256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242954448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242951952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242955600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242955024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242955216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242955408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242952912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242956560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242955984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242956176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242956752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242957136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242955792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242954832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242956368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241680592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242956944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242953872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241680208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241679632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241679440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241679824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241681552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241680976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241681168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241681360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241680400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241682512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241681936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241682128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241682320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241680016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241683472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241682896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241683088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241683280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241680784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241684432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241683856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241684048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241684240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241681744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241685392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241684816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241685008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241685200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241682704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241686352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241685776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241685968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241686160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241683664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241687312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241686736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241686928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241687120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241684624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241688272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241687696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241687888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241688080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241685584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241689232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241688656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241688848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241689040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241686544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241690192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241689616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241689808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241690000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241687504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241691152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241690576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241690768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241690960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241688464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241692112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241691536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241691728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241691920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241689424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241693072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241692496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241692688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241692880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241690384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241694032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241693456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241693648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241693840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241691344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241694992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241694416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241694608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241695184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241695568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241694224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241693264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241694800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242499600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241695376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122241692304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242500176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140122242499024: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite: /content/drive/MyDrive/CSE-51/8Th/Capstone/Breast_Models/busi_mobilenetv2.tflite
# Labels: /content/drive/MyDrive/CSE-51/8Th/Capstone/Breast_Models/labels.json

# %% [markdown]
# # **🌐 সেল–৫: Flask API (HTTPS, CORS, Stable JSON)**

# %%
# ===== Cell 5: Flask API (HTTPS via ngrok) =====
NGROK_AUTH_TOKEN = "33xh8m6mldTf4b78c6hghfHv5LZ_4M5etTYWcNxUBFPdPAooH"  # ✅ your token

# ---- fallback labels (if not loaded from earlier cells) ----
CLASSES = ["benign", "malignant", "normal"]
class_to_idx = {c:i for i,c in enumerate(CLASSES)}
idx_to_class = {i:c for c,i in class_to_idx.items()}

import os, io, time, numpy as np
from flask import Flask, request, jsonify
from flask_cors import CORS
from pyngrok import ngrok

# ====== Flask Config ======
API_VERSION = "v1.0"
MODEL_NAME  = "busi_mobilenetv2"
MODEL_INFO  = {
    "name": MODEL_NAME,
    "version": API_VERSION,
    "input_size": [224,224,3],
    "classes": CLASSES,
    "dtype": "float32"
}

# --- Dummy infer_probs (for API test) ---
# 👉 যদি তুমি আগের infer_probs() define করে রাখো, এটা ডিলিট করে দিও
def infer_probs(image_bytes):
    import random
    p = np.random.dirichlet(np.ones(len(CLASSES)), size=1)[0]
    return p

def make_reason(label:str, probs:list):
    if label == "malignant":
        return "Model suggests malignant features with high probability."
    if label == "benign":
        return "Benign pattern indicated; follow clinical guidance."
    return "No tumor-like pattern detected; clinical correlation advised."

# ====== Flask App ======
app = Flask(__name__)
CORS(app)
app.config['MAX_CONTENT_LENGTH'] = 20 * 1024 * 1024  # 20MB

@app.route("/", methods=["GET"])
def root():
    return "✅ SonaDx Flask API running!"

@app.route("/health", methods=["GET"])
def health():
    return jsonify(ok=True, version=API_VERSION, model=MODEL_INFO)

@app.route("/predict", methods=["POST"])
def predict():
    t0 = time.time()
    if 'file' not in request.files:
        return jsonify(ok=False, error="form-data field 'file' missing"), 400

    f = request.files['file']
    raw = f.read()
    try:
        probs = infer_probs(raw)
        idx   = int(np.argmax(probs))
        label = idx_to_class[idx]
        conf  = float(probs[idx])
        tumor_prob = float(probs[class_to_idx["benign"]] + probs[class_to_idx["malignant"]])
        resp = {
            "ok": True,
            "label": label,
            "confidence": conf,
            "probs": { CLASSES[i]: float(probs[i]) for i in range(len(CLASSES)) },
            "tumor_probability": tumor_prob,
            "reason": make_reason(label, probs),
            "model": MODEL_INFO,
            "latency_ms": int((time.time()-t0)*1000)
        }
        return jsonify(resp)
    except Exception as e:
        return jsonify(ok=False, error=str(e)), 500

# ====== Secure ngrok setup ======
ngrok.set_auth_token(NGROK_AUTH_TOKEN)
public_url = ngrok.connect(5000, bind_tls=True)
print(f"🌐 Public URL (copy this): {public_url.public_url}")

# ====== Run Flask ======
app.run(port=5000)
# Out:
# 🌐 Public URL (copy this): https://sunday-unconfounding-afterwards.ngrok-free.dev
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [12/Oct/2025 13:55:32] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [12/Oct/2025 15:54:24] "GET / HTTP/1.1" 200 -
